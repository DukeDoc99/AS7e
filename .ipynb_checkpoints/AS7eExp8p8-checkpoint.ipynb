# %% [markdown]
# """<br>
# Alexander & Sadiku 7e<br>
# Chapter 8 Example 8<br><hr>
# Notebook by Michael R. Gustafson II (mrg@duke.edu)<br>
# Spring 2022 Version<br>
# """

# %%
import sympy as sym
from sym_helper import eqnsubs

# %%
sym.init_printing()

# %%
# Declare symbols
sym.var('R1, R2, L, C, t')
sym.var('vright, ileft, vc, il', cls=sym.Function)
unks = [vc(t), il(t)]

# %%
# Known values and functions
elevar = [R1, R2, L, C]
eleval = [20, 20, 20, 8e-3]
funvar = [vright(t), ileft(t)]
oldfunvals = [30, 4]
newfunvals = [0, 4]

# %%
# DCSS Equations and solutions
ss1 = il(0)-ileft(t)
ss2 = vc(0)/R1+(vc(0)-vright(t))/R2
oldeqns = [ss1, ss2]
oldeqns
# Out:
# ⎡                  vc(0) - vright(t)   vc(0)⎤
# ⎢il(0) - ileft(t), ───────────────── + ─────⎥
# ⎣                          R₂            R₁ ⎦

# %%
noldeqns = eqnsubs(oldeqns, elevar+funvar, eleval+oldfunvals)
noldeqns
# Out:
# ⎡           vc(0)   3⎤
# ⎢il(0) - 4, ───── - ─⎥
# ⎣             10    2⎦

# %%
icsoln = sym.solve(noldeqns)
icsoln
# Out:
# [{il(0): 4, vc(0): 15}]

# %%
# Model equations
KCLn1 = -ileft(t) + il(t) + vc(t)/R1 + C*vc(t).diff(t) + (vc(t)-vright(t))/R2
KVLl2 = vc(t) - L*il(t).diff(t)

# %%
# Collect equations
eqns = [KCLn1, KVLl2]
eqns
# Out:
# ⎡  d                              vc(t) - vright(t)   vc(t)      d
# ⎢C⋅──(vc(t)) + il(t) - ileft(t) + ───────────────── + ─────, - L⋅──(il(t)) + v
# ⎣  dt                                     R₂            R₁       dt
#
#     ⎤
# c(t)⎥
#     ⎦

# %%
# Make equations numerical
neqns = eqnsubs(eqns, elevar+funvar, eleval+newfunvals)
neqns
# Out:
# ⎡        vc(t)         d                         d        ⎤
# ⎢il(t) + ───── + 0.008⋅──(vc(t)) - 4, vc(t) - 20⋅──(il(t))⎥
# ⎣          10          dt                        dt       ⎦

# %%
# Solve and display
sol = sym.dsolve(neqns, unks, ics=icsoln[0])
sol
# Out:
# ⎡                                                 -11.9782196186948⋅t
# ⎣vc(t) = -1.4210854715202e-14 + 15.6831708838498⋅ℯ                    - 0.6831
#
#              -0.5217803813052⋅t                                    -11.9782196
# 70883849797⋅ℯ                  , il(t) = 4.0 - 0.0654653670707981⋅ℯ
#
# 186948⋅t                       -0.5217803813052⋅t⎤
#          + 0.0654653670708054⋅ℯ                  ⎦

# %%
sym.plot(sol[0].rhs, (t, 0, 2), xlabel="t", ylabel=r"$v_C(t)$", show=False).save("AS7eExp8p8plot1.png")

# %%
p2=sym.plot(sol[1].rhs, (t, 0, 2), xlabel="t", ylabel=r"$i_L(t)$", show=False).save("AS7eExp8p8plot2.png")
